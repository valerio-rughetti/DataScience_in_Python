# %% [markdown]
# # Tidy Datasets

# %%
# %pip install -r https://raw.githubusercontent.com/vrughetti/python4DS/main/requirements.txt

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Untidy Data example

# %%
untidy_data = {
    'Name': ['John', 'Mary', 'Adam'],
    'Maths': [80, 90, 75],
    'Science': [85, 92, 78],
    'English': [70, 88, 82]
}

df_untidy = pd.DataFrame(untidy_data)
df_untidy.head()
# Out:
#    Name  Maths  Science  English
# 0  John     80       85       70
# 1  Mary     90       92       88
# 2  Adam     75       78       82

# %% [markdown]
# Let's transform the previous dataset into a tidy dataset. We will make use of melt() function from pandas library.
#
# ```python
#
# df_untidy.melt(id_vars='Name',var_name='Subject',value_name='Score')
#
# ```

# %%
df_tidy = df_untidy.melt(id_vars='Name', var_name='Subject', value_name='Score')
df_tidy.head()
# Out:
#    Name  Subject  Score
# 0  John    Maths     80
# 1  Mary    Maths     90
# 2  Adam    Maths     75
# 3  John  Science     85
# 4  Mary  Science     92

# %% [markdown]
# So now we have a tidy dataset. Let's see how we can untidy it.
#
# ```python
#
# df_tidy.pivot(index='Name',columns='Subject',values='Score')
#
# ```

# %%
df_untidy_from_tidy = df_tidy.pivot(index='Name', columns='Subject', values='Score')
df_untidy_from_tidy.columns.name = None
df_untidy_from_tidy = df_untidy_from_tidy.reset_index()
df_untidy_from_tidy.head()
# Out:
#    Name  English  Maths  Science
# 0  Adam       82     75       78
# 1  John       70     80       85
# 2  Mary       88     90       92

# %% [markdown]
# ## Long and Wide Format

# %%
df = pd.DataFrame(
    {
        'year': np.random.randint(1950, 1970, size=20),
        'month': np.random.randint(1, 13, size=20),
        'passengers': np.random.randint(100, 1000, size=20)
    }
)
df.head()
# Out:
#    year  month  passengers
# 0  1957      5         593
# 1  1963      1         479
# 2  1955      6         933
# 3  1967      1         235
# 4  1962      2         768

# %% [markdown]
# From long to wide format:
#
# ```python
# df.pivot(index=..., columns=..., values=...)
# ```

# %%
df.pivot(index='year', columns='month', values='passengers')
# Out:
# month     1      2      3      4      5      6      7      8      9      12
# year
# 1950     NaN    NaN    NaN    NaN    NaN    NaN    NaN  737.0    NaN    NaN
# 1955     NaN    NaN    NaN    NaN    NaN  933.0  440.0    NaN    NaN    NaN
# 1956     NaN    NaN    NaN  275.0    NaN    NaN    NaN    NaN    NaN    NaN
# 1957     NaN    NaN    NaN  476.0  593.0    NaN    NaN    NaN    NaN  986.0
# 1959   272.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN  444.0    NaN
# 1961     NaN    NaN  643.0    NaN  328.0    NaN  945.0    NaN    NaN    NaN
# 1962     NaN  768.0    NaN  843.0    NaN    NaN    NaN    NaN    NaN    NaN
# 1963   479.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1965     NaN    NaN    NaN    NaN  769.0    NaN    NaN    NaN    NaN  563.0
# 1967   235.0    NaN  509.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1969     NaN  253.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN

# %% [markdown]
# If there are no values for a particular combination of index and column, then NaN is returned.

# %% [markdown]
# ---
#
# # What's next?
#
# Next notebook: [Overview of Pandas](https://github.com/vrughetti/python4DS/blob/main/notebooks/pandas/pandas.ipynb)
